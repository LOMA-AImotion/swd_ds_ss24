# %%
import numpy as np

groessen = np.array([174.0, 175.5, 180.5, 194, 200, 186.0, 172.0])
print(np.mean(groessen))
print(np.std(groessen))
# Out:
# 183.14285714285714
# 9.880407328627289

# %%
print(groessen)
mittelwert, stdabweichung = np.mean(groessen), np.std(groessen)
# Out:
# [168. 210. 172. 174. 158.]

# %% [markdown]
# Gebe die Standarbweichung aus und den Mittelwert

# %%
print(mittelwert)
print(stdabweichung)
# Out:
# 176.4
# 17.681628884240276

# %%
import matplotlib.pyplot as plt

plt.hist(groessen, bins=10, alpha=0.7, color="blue")
plt.title("Größenverteilung der Stichprobe")
plt.xlabel("Größe (cm)")
plt.ylabel("Häufigkeit")
# Out:
# Text(0, 0.5, 'Häufigkeit')

# %%
groessen = np.array([168.0, 210.0, 172.0, 174.0, 158.0])
